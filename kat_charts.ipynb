# %%
#import dependencies
from pathlib import Path
from matplotlib import pyplot as plt
from scipy import stats
import numpy as np
import pandas as pd
import scipy.stats as st

# %%
#Create a path to the data
path = Path("Resources/clean_consolidated_data.csv")

#read the data and convert it to a dataframe
df=pd.read_csv(path, low_memory=False)
df.head()
# Out:
#    Unnamed: 0.2  Unnamed: 0.1  Unnamed: 0  UNITID  \
# 0             0             0           0  100654
# 1             1             1           1  100663
# 2             2             2           3  100706
# 3             3             3           4  100724
# 4             4             4           5  100751
#
#                       Institution Name State     Region  Predominant Degree  \
# 0             Alabama A & M University    AL  Southeast                   3
# 1  University of Alabama at Birmingham    AL  Southeast                   3
# 2  University of Alabama in Huntsville    AL  Southeast                   3
# 3             Alabama State University    AL  Southeast                   3
# 4            The University of Alabama    AL  Southeast                   3
#
#        Type of School  Admission Rate  ...  Bachelor of Engineering  \
# 0  Private For-Profit          0.5010  ...                      1.0
# ...

# %%
#Region summary table

summary_df =df.groupby(['Region']).agg({'Debt repayment rate among grads - 5 years':['mean', 'median', 'var', 'std', 'sem']})
summary_df
# Out:
#           Debt repayment rate among grads - 5 years                      \
#                                                mean    median       var
# Region
# Southeast                                  0.856808  0.881944  0.008215
#
#
#                 std       sem
# Region
# Southeast  0.090636  0.002389

# %%
#Bar chart for Region vs. Debt repayment rate 5 years


summary_df =clean_df.groupby(['Drug Regimen']).agg({'Tumor Volume (mm3)':['mean', 'median', 'var', 'std', 'sem']})
summary_df2
'Region'
'Debt repayment rate among grads - 5 years'





#grab column of data from larger dataframe and collect the value counts of that column. 
bar_data =clean_df['Drug Regimen'].value_counts()

#plot just the column of data collected and format the data labels
bar_data.plot(kind='bar',xlabel="Drug Regimen", ylabel="# of Observed Mouse Timepoints")
plt.show()
